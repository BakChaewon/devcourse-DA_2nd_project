# %%
import pandas as pd

# %%
pakistan_dataset=pd.read_csv('Pakistan Largest Ecommerce Dataset.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\1945846750.py:1: DtypeWarning: Columns (1,2,3,7,8,9,11,12,13,14,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   parkistan_dataset=pd.read_csv('Pakistan Largest Ecommerce Dataset.csv')

# %%
pakistan_dataset.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
pakistan_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %%
pakistan_dataset.dtypes
# Out:
# item_id                  float64
# status                    object
# created_at                object
# sku                       object
# price                    float64
# qty_ordered              float64
# grand_total              float64
# increment_id              object
# category_name_1           object
# sales_commission_code     object
# discount_amount          float64
# payment_method            object
# Working Date              object
# BI Status                 object
#  MV                       object
# Year                     float64
# Month                    float64
# Customer Since            object
# M-Y                       object
# FY                        object
# Customer ID              float64
# Unnamed: 21              float64
# Unnamed: 22              float64
# Unnamed: 23              float64
# Unnamed: 24              float64
# Unnamed: 25              float64
# dtype: object

# %% [markdown]
# ## 결측치 처리

# %%
pakistan_dataset.drop(['Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1, inplace=True)
pakistan_dataset.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
null_rows =parkistan_dataset.isnull()
null_rows
# Out:
#         item_id  status  created_at    sku  price  qty_ordered  grand_total  \
# 0         False   False       False  False  False        False        False
# 1         False   False       False  False  False        False        False
# 2         False   False       False  False  False        False        False
# 3         False   False       False  False  False        False        False
# 4         False   False       False  False  False        False        False
# ...         ...     ...         ...    ...    ...          ...          ...
# 584519    False   False       False  False  False        False        False
# 584520    False   False       False  False  False        False        False
# 584521    False   False       False  False  False        False        False
# 584522    False   False       False  False  False        False        False
# 584523    False   False       False  False  False        False        False
#
# ...

# %%
# 완전히 Null 값으로 이루어진 행 삭제
pakistan_dataset= parkistan_dataset.dropna(how='all')
pakistan_dataset
# Out:
#          item_id          status created_at  \
# 0       211131.0        complete   7/1/2016
# 1       211133.0        canceled   7/1/2016
# 2       211134.0        canceled   7/1/2016
# 3       211135.0        complete   7/1/2016
# 4       211136.0  order_refunded   7/1/2016
# ...          ...             ...        ...
# 584519  905204.0             cod  8/28/2018
# 584520  905205.0      processing  8/28/2018
# 584521  905206.0      processing  8/28/2018
# 584522  905207.0      processing  8/28/2018
# 584523  905208.0      processing  8/28/2018
#
#                                                       sku     price  \
# 0                                       kreations_YI 06-L    1950.0
# 1       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...     240.0
# 2                                      Ego_UP0017-999-MR0    2450.0
# 3                                          kcc_krone deal     360.0
# 4                                             BK7010400AG     555.0
# ...

# %%
pakistan_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 584524 entries, 0 to 584523
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %%
pakistan_dataset['status'].unique()
# Out:
# array(['complete', 'canceled', 'order_refunded', 'received', 'refund',
#        'closed', 'fraud', 'holded', 'exchange', 'pending_paypal', 'paid',
#        '\\N', 'cod', 'pending', nan, 'processing', 'payment_review'],
#       dtype=object)

# %%
filtered_df = pakistan_dataset[(pakistan_dataset['status'] == '\\N') | (pakistan_dataset['status'].isnull())]
filtered_df

# %%
filtered_df = pakistan_dataset[(pakistan_dataset['status'] == '\\N') | (pd.isna(pakistan_dataset['status']))]
filtered_df
# Out:
#          item_id status created_at                              sku    price  \
# 255520  526623.0     \N   7/3/2017                   test-product-3      3.0
# 255521  526624.0     \N   7/3/2017                     test-product     75.0
# 255624  526754.0     \N   7/3/2017                   test-product-3      3.0
# 255625  526755.0     \N   7/3/2017                     test-product     75.0
# 477519  783751.0    NaN  3/15/2018              OTHPCB5A7D8A0BD10E8   8000.0
# 513736  827187.0    NaN  4/16/2018           KABOXF5ABCC75C7E2F7-32    370.0
# 513737  827189.0    NaN  4/16/2018  KABSHO5AA77C331466F-11-13 Years    473.0
# 513738  827191.0    NaN  4/16/2018    KABBIN5A93E074C501A-8-9 Years    749.0
# 513739  827193.0    NaN  4/16/2018  KABLIT59AC117FD51C4-12-13 Years    692.0
# 513740  827195.0    NaN  4/16/2018    KABCOL5AB2B8019805C-8-9 Years    423.0
# 518706  832777.0    NaN  4/30/2018              ENTCLI5A5DD7D800D6E   6042.0
# ...

# %%
## 'status' 열의 null값 특정 값으로 바꾸기
pakistan_dataset['status'] = pakistan_dataset['status'].fillna('holded')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4464\2473496178.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parkistan_dataset['status'] = parkistan_dataset['status'].fillna('holded')

# %%
null_row=pakistan_dataset[pakistan_dataset['sku'].isnull()]
null_row
# Out:
#          item_id          status  created_at  sku    price  qty_ordered  \
# 14846   230008.0        canceled   8/13/2016  NaN      0.0          1.0
# 20676   236830.0        canceled    9/1/2016  NaN      0.0          1.0
# 39838   260006.0        canceled   10/7/2016  NaN      0.0          1.0
# 39839   260007.0        canceled   10/7/2016  NaN      0.0          3.0
# 39880   260061.0        canceled   10/7/2016  NaN      0.0          3.0
# 124968  367292.0          refund  12/10/2016  NaN      0.0          1.0
# 125636  368122.0          refund  12/12/2016  NaN      0.0          1.0
# 125811  368362.0          refund  12/13/2016  NaN      0.0          1.0
# 149597  399798.0          refund    2/7/2017  NaN      0.0          1.0
# 170249  426105.0        canceled   3/21/2017  NaN      0.0          1.0
# 170401  426302.0        canceled   3/22/2017  NaN      0.0          1.0
# 173040  429392.0          refund   3/23/2017  NaN      0.0          1.0
# ...

# %%
## 'sku' 열의 null값 특정 값으로 바꾸기
pakistan_dataset[pakistan_dataset['sku']=='\\N']
# Out:
#          item_id          status  created_at sku    price  qty_ordered  \
# 14846   230008.0        canceled   8/13/2016  \N      0.0          1.0
# 20676   236830.0        canceled    9/1/2016  \N      0.0          1.0
# 39838   260006.0        canceled   10/7/2016  \N      0.0          1.0
# 39839   260007.0        canceled   10/7/2016  \N      0.0          3.0
# 39880   260061.0        canceled   10/7/2016  \N      0.0          3.0
# 124968  367292.0          refund  12/10/2016  \N      0.0          1.0
# 125636  368122.0          refund  12/12/2016  \N      0.0          1.0
# 125811  368362.0          refund  12/13/2016  \N      0.0          1.0
# 149597  399798.0          refund    2/7/2017  \N      0.0          1.0
# 170249  426105.0        canceled   3/21/2017  \N      0.0          1.0
# 170401  426302.0        canceled   3/22/2017  \N      0.0          1.0
# 173040  429392.0          refund   3/23/2017  \N      0.0          1.0
# ...

# %%
null_row=pakistan_dataset[pakistan_dataset['category_name_1'].isnull()]
null_row
# Out:
#          item_id          status created_at                    sku  price  \
# 425895  725194.0  order_refunded   1/2/2018  MEFQMO59B0942707B79-L   99.0
# 431194  731122.0        received  1/15/2018  MEFQMO59B0942707B79-M   99.0
# 432492  732569.0        canceled  1/19/2018  MEFQMO59B0942707B79-M   99.0
# 432494  732572.0        canceled  1/19/2018  MEFQMO59B0942707B79-M   99.0
# 432496  732575.0  order_refunded  1/19/2018  MEFQMO59B0942707B79-M   99.0
# ...          ...             ...        ...                    ...    ...
# 535572  850761.0        received  5/16/2018    KABASA5ABC763F62E76  506.0
# 541927  857600.0        received  5/25/2018    WOFASA5AE962A6DD038  199.0
# 549314  865823.0        canceled   6/4/2018  MEFQMO59B0942707B79-M   99.0
# 568069  886699.0        canceled  7/18/2018     COMWD5AA8FF5851E73  314.0
# 580564  900744.0        received  8/15/2018     COMWD5AA8FF5851E73  314.0
#
#         qty_ordered  grand_total increment_id category_name_1  \
# ...

# %%
## 'category' 열의 null값 특정 값으로 바꾸기
pakistan_dataset['category_name_1'] = pakistan_dataset['category_name_1'].fillna('\\N')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4464\120944421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parkistan_dataset['category_name_1'] = parkistan_dataset['category_name_1'].fillna('\\N')

# %%
pakistan_dataset[pakistan_dataset['sales_commission_code'].isnull()]
# Out:
#          item_id      status created_at  \
# 135887  381711.0    complete   1/4/2017
# 135888  381713.0    complete   1/4/2017
# 135889  381714.0    complete   1/4/2017
# 135890  381716.0    complete   1/4/2017
# 281723  557053.0    complete  8/10/2017
# ...          ...         ...        ...
# 584519  905204.0         cod  8/28/2018
# 584520  905205.0  processing  8/28/2018
# 584521  905206.0  processing  8/28/2018
# 584522  905207.0  processing  8/28/2018
# 584523  905208.0  processing  8/28/2018
#
#                                           sku     price  qty_ordered  \
# 135887                   jockey_J260-1013-3-M     715.0          1.0
# 135888                   BO_nonRC-Jeep-Silver     250.0          1.0
# 135889                      aybeez_ABZ-3338-M     299.0          1.0
# 135890                       PC_3P COMBED-008     450.0          1.0
# 281723  JSM_JSM-003-ComboGreenWhitePakShirt-M     180.0          2.0
# ...

# %%
pakistan_dataset['sales_commission_code'].fillna('\\N', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4464\2289190087.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parkistan_dataset['sales_commission_code'].fillna('\\N', inplace=True)

# %%
pakistan_dataset[pakistan_dataset['Customer Since'].isnull()]
# Out:
#          item_id          status created_at                    sku   price  \
# 427377  726862.0  order_refunded   1/5/2018    BAGLOR5A12C5C756AE5   209.0
# 427378  726863.0  order_refunded   1/5/2018    WOFGUL59C24CC9BE5D9   720.0
# 427379  726864.0  order_refunded   1/5/2018    BAGNAD59E0AAC250E6D   145.0
# 437567  738191.0  order_refunded  1/31/2018  MEFMUN5A0ACC3A894BE-9   999.0
# 478699  784981.0        received  3/15/2018    OTHPCB5A7D8A0DA56C6  8000.0
# 478779  785061.0        canceled  3/15/2018    OTHPCB5A7D8A0DA56C6  8000.0
# 494278  804621.0        canceled  3/27/2018    OTHPCB5AB351ED6A8F2  5000.0
# 495340  805750.0        canceled  3/27/2018    OTHPCB5AB351ECC7118   500.0
# 495945  807010.0        canceled  3/27/2018    OTHPCB5AB351EEC46EC   500.0
# 496921  808287.0  order_refunded  3/27/2018  MEFKAR5A7C138CE9EBD-L  1040.0
# 502446  814174.0        canceled  3/28/2018    OTHPCB5ABB207673754  2000.0
#
#         qty_ordered  grand_total increment_id    category_name_1  \
# ...

# %%
null_counts = pakistan_dataset.isnull().sum()
null_counts
# Out:
# item_id                   0
# status                    0
# created_at                0
# sku                       0
# price                     0
# qty_ordered               0
# grand_total               0
# increment_id              0
# category_name_1           0
# sales_commission_code     0
# discount_amount           0
# payment_method            0
# Working Date              0
# BI Status                 0
#  MV                       0
# Year                      0
# Month                     0
# Customer Since           11
# M-Y                       0
# FY                        0
# Customer ID              11
# dtype: int64

# %%
pakistan_dataset['Customer ID'].fillna('nonmember', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4464\2078691950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parkistan_dataset['Customer ID'].fillna('nonmember', inplace=True)

# %%
null_counts = parkistan_dataset.isnull().sum()
null_counts
# Out:
# item_id                  0
# status                   0
# created_at               0
# sku                      0
# price                    0
# qty_ordered              0
# grand_total              0
# increment_id             0
# category_name_1          0
# sales_commission_code    0
# discount_amount          0
# payment_method           0
# Working Date             0
# BI Status                0
#  MV                      0
# Year                     0
# Month                    0
# Customer Since           0
# M-Y                      0
# FY                       0
# Customer ID              0
# dtype: int64

# %%
pakistan_dataset['BI Status'] = pakistan_dataset['BI Status'].replace(['#REF!'], ['\\N'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4464\1580444936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parkistan_dataset['BI Status'] = parkistan_dataset['BI Status'].replace(['#REF!'], ['\\N'])

# %% [markdown]
# ## Type 변환

# %%
# DATE TYPE으로 변환
pakistan_dataset['Working Date']=pd.to_datetime(pakistan_dataset['Working Date'])

# %%
pakistan_dataset.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete 2016-07-01
# 1  211133.0        canceled 2016-07-01
# 2  211134.0        canceled 2016-07-01
# 3  211135.0        complete 2016-07-01
# 4  211136.0  order_refunded 2016-07-01
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
pakistan_dataset['created_at']
# Out:
# 0          7/1/2016
# 1          7/1/2016
# 2          7/1/2016
# 3          7/1/2016
# 4          7/1/2016
#              ...
# 1048570         NaN
# 1048571         NaN
# 1048572         NaN
# 1048573         NaN
# 1048574         NaN
# Name: created_at, Length: 1048575, dtype: object

# %%
pakistan_dataset['created_at']=pd.to_datetime(pakistan_dataset['created_at'])

# %%
pakistan_dataset['created_at']=pakistan_dataset['created_at'].dt.to_period('M')
pakistan_dataset['created_at']
# Out:
# 0          2016-07
# 1          2016-07
# 2          2016-07
# 3          2016-07
# 4          2016-07
#             ...
# 1048570        NaT
# 1048571        NaT
# 1048572        NaT
# 1048573        NaT
# 1048574        NaT
# Name: created_at, Length: 1048575, dtype: period[M]

# %%
pakistan_dataset['Month'] = pakistan_dataset['Month'].astype(int)

# %%
pakistan_dataset['created_at']=pd.to_datetime(pakistan_dataset['created_at'])

# %%
pd.to_datetime(pakistan_dataset['Customer Since']).dt.to_period('M')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 pd.to_datetime(parkistan_dataset['Customer Since']).dt.to_period('M')
#
# File C:\anaconda\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File C:\anaconda\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# ...

# %%
pakistan_dataset['M-Y'] = pd.to_datetime(pakistan_dataset['M-Y']).dt.to_period('M')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11012\1075926685.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parkistan_dataset['M-Y'] = pd.to_datetime(parkistan_dataset['M-Y']).dt.to_period('M')

# %%
pakistan_dataset['M-Y'] = pd.to_datetime(pakistan_dataset['M-Y'], format='%m-%Y').dt.to_period('M')

# %%
pakistan_dataset.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete 2016-07-01
# 1  211133.0        canceled 2016-07-01
# 2  211134.0        canceled 2016-07-01
# 3  211135.0        complete 2016-07-01
# 4  211136.0  order_refunded 2016-07-01
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
pakistan_dataset['MV'] = pakistan_dataset['MV'].str.replace(',', '')  # 쉼표 제거
pakistan_dataset['MV'] = pakistan_dataset['MV'].str.strip()
pakistan_dataset['MV'] = pakistan_dataset['MV'].replace('-', '0').astype(int)

# %% [markdown]
# ## 컬럼명 변경 및 삭제

# %%
# 컬럼 명 변결
pakistan_data.rename(columns={'category_name_1':'category',
                    'Working Date':'working_date',
                    'Year':'year',
                    'Month':'month',
                    'Customer Since':'customer_since',
                    'Customer ID':'customer_id'}, inplace=True)
pakistan_data

# %%
# 컬럼 제거
pakistan_data.drop(columns=['working_date','M-Y'], inplace=True)

# %% [markdown]
# ## 그룹핑

# %%
pakistan_group = pakistan_data

# %%
pakistan_group['status'].replace(['received','paid','closed'],'complete', inplace=True) # 완료됨
pakistan_group['status'].replace(['order_refunded'],'refund', inplace=True) # 환불
pakistan_group['status'].replace(['cod','paid','payment_review','pending','holded','pending_paypal'], 'processing', inplace=True) # 진행중, 결제 안됨
pakistan_group['status'].replace(['exchange','\\N','fraud'], 'others', inplace=True) # others
# canceled
pakistan_group['status'].unique()

# %%
pakistan_group['payment_method'].replace(['Payaxis', 'internetbanking','mcblite', 'ublcreditcard', 'bankalfalah'], 'Banks/Cards/Wallets', inplace=True)
pakistan_group['payment_method'].replace(['easypay_voucher', 'Easypay', 'Easypay_MA'], 'Easypay', inplace=True)
pakistan_group['payment_method'].replace(['jazzwallet', 'jazzvoucher'], 'JazzCash', inplace=True)
pakistan_group['payment_method'].replace(['cashatdoorstep', 'cod'], 'Cash on Delivery', inplace=True)
pakistan_group['payment_method'].replace(['customercredit', 'apg', 'mygateway', 'productcredit','marketingexpense', 'financesettlement'], 'Others', inplace=True)
pakistan_group.head()
